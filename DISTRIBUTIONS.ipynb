# %% [markdown]
# #ASSIGNMENT - DISTRIBUTIONS
#
# 1. Stimulate 30 rolls with =RANDBETWEEN(1,6). What is the probability of rolling a 3 exactly 5 times? (Hint: Use
# BINOM.DIST)
#     - PROBABILITY OF GETTING A 3 ON ONE ROLL
#       P=1/6
#     - Number of trails = 30
#     - want the number exaclty  = 5 times
#     - After applying formula it gives 0.19 , So the probability of rolling a 3 exaclty 5 times is 19.21%.
#
# 2. Generate 100 values in Excel using the continuous uniform distribution RAND() and plot a histogram.
# Describe the shape of the distribution
#     - In this Histogram ( represented in excel sheet ) has given values from 1 to 100 , and every value has nearly possibility of occuring.
#     - A rectangular distributions with values evenly spread across the interval 1 to 100.
#
# 3. A dataset has a mean of 50 and a standard deviation of 5. What percentage of values lie between 45 and
# 55 if the data follows a normal distribution?
#     - mean = 50
#     - standard deviation = 5
#     - the interval = 45 to 55 , 50-5 = 45 . 50+5= 55
#     - About 68% of the value lies between 45 and 55
#
# 4. What is the concept of standardization (z-score), and why is it important in data analysis? Explain the
# formula and how standardization transforms a dataset.
#     - Standardization (Z SCORE) is statistical techniquue used to transform data sso that , Mean= 0, Standard deviation= 1,
#     The value is called - z-scoree.
#     z=x−μ​  / σ .
#     - Lets understand this with an example , Mean= 50, SD= 5 Data = 60
#     z= 60-50/5 ; z= 2
#     - It makes Diffferent Datasets comparable, example - Height in cm and Salaries in (₹) , after standardization both are on same scale.
#
# 5. What is Kurtosis and their type?
#     -  Kurtosis is a statistical measure that describes the shape of a distribution.
#     - Types of Kurtosis - 1) Mesokurtic ; 2) Leptokurtic , 3) Platykurtic
#
# 6. Explain why the uniform distribution is a good model for the outcome of rolling a fair die.
#     - A uniform distribution is a good model for rolling a fair die because: A fair die has 6 possible outcomes:
# 1,2,3,4,5,6
#     - equal probability of occuring = 1/6
#     - It is a good model because Equal Likelihood , Fixed Range , Constant Probability ,
#     - Types of Uniform Distributions rolling a die follows is - Discrete Uniform Distributions because Outcomes are countable integers and all outcomes are equally likely .
#
# 7. Use Excel to compute the probability of getting at least 8 successes in 15 trials with success probability 0.5
#    - No. of trails = 15
#    - probability of success = 0.5
#    - subtract probability upto 7 success = 7
#    - The probability is = 0.5
#
# 8. How does log transformation help in stabilizing variance and making data more normally distributed?
#     - A log transformation means replacing each data value x with: log(x)  , It is used to make data easier to analyze, especially when the data is highly skewed or has unequal variance.
#     - How it helps ,
#     1. Stabilizes Variance , In many datasets, larger values show much greater spread than smaller values.
#      OIGINAL VALUES = 10, 100 , 1000
#      AFTER LOG = 1, 2, 3
#    2. Makes Data More Normally Distributed as Most values are small and Few values are extremely large.
